# %% [markdown]
# #### Data laod

# %%
import pandas as pd 

df = pd.read_csv(r'..\data\raw.csv')

# %%
df.shape
# Out:
# (120000, 17)

# %%
df.isnull().sum()
# Out:
# user_id               0
# session_id            0
# date                  0
# month                 0
# channel               0
# campaign_type         0
# device                0
# user_type             0
# region                0
# visited_website       0
# viewed_product        0
# added_to_cart         0
# checkout_started      0
# purchase_completed    0
# discount_applied      0
# order_value           0
# revenue               0
# dtype: int64

# %%
df.dtypes
# Out:
# user_id                 int64
# session_id              int64
# date                      str
# month                     str
# channel                   str
# campaign_type             str
# device                    str
# user_type                 str
# region                    str
# visited_website           str
# viewed_product            str
# added_to_cart             str
# checkout_started          str
# purchase_completed        str
# discount_applied          str
# order_value           float64
# revenue               float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[['order_value','revenue']].describe()
# Out:
#          order_value        revenue
# count  120000.000000  120000.000000
# mean      614.962674     141.804993
# std       456.130268     545.359126
# min       499.000000       0.000000
# 25%       499.000000       0.000000
# 50%       499.000000       0.000000
# 75%       499.000000       0.000000
# max      4741.370000    4741.370000

# %%
df[(df['viewed_product']=='No') & (df['added_to_cart']=='Yes')]
# Out:
# Empty DataFrame
# Columns: [user_id, session_id, date, month, channel, campaign_type, device, user_type, region, visited_website, viewed_product, added_to_cart, checkout_started, purchase_completed, discount_applied, order_value, revenue]
# Index: []

# %%
df[(df['added_to_cart']=='No') & (df['checkout_started']=='Yes')]
# Out:
# Empty DataFrame
# Columns: [user_id, session_id, date, month, channel, campaign_type, device, user_type, region, visited_website, viewed_product, added_to_cart, checkout_started, purchase_completed, discount_applied, order_value, revenue]
# Index: []

# %%
df[(df['checkout_started']=='No') & (df['purchase_completed']=='Yes')]
# Out:
# Empty DataFrame
# Columns: [user_id, session_id, date, month, channel, campaign_type, device, user_type, region, visited_website, viewed_product, added_to_cart, checkout_started, purchase_completed, discount_applied, order_value, revenue]
# Index: []

# %%
df[df['purchase_completed']=='No']['revenue'].sum()
# Out:
# np.float64(0.0)

# %%
df['date'] = pd.to_datetime(df['date'],format='%m/%d/%Y')

# %%
df.columns
# Out:
# Index(['user_id', 'session_id', 'date', 'month', 'channel', 'campaign_type',
#        'device', 'user_type', 'region', 'visited_website', 'viewed_product',
#        'added_to_cart', 'checkout_started', 'purchase_completed',
#        'discount_applied', 'order_value', 'revenue'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
for col in ['channel','campaign_type','device','user_type','region']:
    print(col,df[col].unique())
# Out:
# channel <ArrowStringArray>
# ['Organic', 'Paid Ads', 'Social', 'Email']
# Length: 4, dtype: str
# campaign_type <ArrowStringArray>
# ['New Launch', 'Influencer', 'Discount']
# Length: 3, dtype: str
# device <ArrowStringArray>
# ['Mobile', 'Desktop']
# Length: 2, dtype: str
# user_type <ArrowStringArray>
# ['New', 'Returning']
# Length: 2, dtype: str
# region <ArrowStringArray>
# ['Metro', 'Non-Metro']
# Length: 2, dtype: str

# %%
df.to_csv(r'..\data\cleaned_data.csv',index=False)

# %%
for col in ['channel', 'campaign_type', 'device', 'user_type', 'region']:
    print(col, df[col].unique())
# Out:
# channel <ArrowStringArray>
# ['Organic', 'Paid Ads', 'Social', 'Email']
# Length: 4, dtype: str
# campaign_type <ArrowStringArray>
# ['New Launch', 'Influencer', 'Discount']
# Length: 3, dtype: str
# device <ArrowStringArray>
# ['Mobile', 'Desktop']
# Length: 2, dtype: str
# user_type <ArrowStringArray>
# ['New', 'Returning']
# Length: 2, dtype: str
# region <ArrowStringArray>
# ['Metro', 'Non-Metro']
# Length: 2, dtype: str

# %%
df.head()
# Out:
#    user_id  session_id       date    month   channel campaign_type  device  \
# 0   221958           1 2025-08-16  2025-08   Organic    New Launch  Mobile
# 1   771155           2 2025-12-16  2025-12   Organic    Influencer  Mobile
# 2   231932           3 2025-07-17  2025-07   Organic    Influencer  Mobile
# 3   465838           4 2025-07-04  2025-07  Paid Ads      Discount  Mobile
# 4   359178           5 2025-08-10  2025-08  Paid Ads    Influencer  Mobile
#
#    user_type     region visited_website viewed_product added_to_cart  \
# 0        New      Metro             Yes             No            No
# 1        New  Non-Metro             Yes            Yes           Yes
# 2        New  Non-Metro             Yes            Yes            No
# 3  Returning      Metro             Yes            Yes           Yes
# 4  Returning  Non-Metro             Yes             No            No
#
#   checkout_started purchase_completed discount_applied  order_value   revenue
# ...
